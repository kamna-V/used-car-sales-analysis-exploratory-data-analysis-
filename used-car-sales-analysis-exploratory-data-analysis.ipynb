# %% [markdown]
#  **USED CAR PRICE
# PREDICTION SYSTEM**

# %% [markdown]
# ***PROBLEM STATEMENT ***
#
# As we know, this year the prices of cars ranging from Maruti, Tata Motors to Mercedes and Audi has increased because of higher input costs and many other reasons. Due to the incapability of customers to buy new cars, mostly due to the lack of funds more and more people are now shifting to buying used cars.
# So in this project we are going to assume a company whose used car sales has been down since the prices rose up even though the sales of used cars is showing a global increase. We will use a used car price prediction system to assist the company in increasing its used car sales by making changes to the features that are causing their low sales.

# %% [markdown]
# **MOTIVATION**
#
# We as a team were required to find a topic that was in common interest to all of us. It so happened to be that Automobile industry was a field in which all of us had a basic idea and hence tried getting datasets that were related to the same.
# Automobile Industry being one of the largest fields, the datasets related to the same were unlimited and humongous in size. We were in search of a dataset which would be both helpful in exploring the data to the maximum and learn as much as possible from the same .Thus we found out the dataset related to used car data predictions which contained the required data for which Exploratory Data Analysis can be done.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas_profiling 
from tkinter import *

# %%
carsales = pd.read_csv('C:\\Users\\SHIVA\\Downloads\\used_car_sales.csv')

# %%
carsales.shape
# Out:
# (9576, 10)

# %%
carsales.head(20)
# Out:
#               car       price       body  mileage  engV engType registration  \
# 0            Ford   15500.000  crossover       68   2.5     Gas          yes
# 1   Mercedes-Benz   20500.000      sedan      173   1.8     Gas          yes
# 2   Mercedes-Benz   35000.000      other      135   5.5  Petrol          yes
# 3   Mercedes-Benz   17800.000        van      162   1.8  Diesel          yes
# 4   Mercedes-Benz   33000.000      vagon       91   NaN   Other          yes
# 5          Nissan   16600.000  crossover       83   2.0  Petrol          yes
# 6           Honda    6500.000      sedan      199   2.0  Petrol          yes
# 7         Renault   10500.000      vagon      185   1.5  Diesel          yes
# 8   Mercedes-Benz   21500.000      sedan      146   1.8     Gas          yes
# 9   Mercedes-Benz   22700.000      sedan      125   2.2  Diesel          yes
# 10         Nissan   20447.154  crossover        0   1.2  Petrol          yes
# 11  Mercedes-Benz   20400.000      sedan      190   1.8     Gas          yes
# 12  Mercedes-Benz   22500.000      sedan      164   1.8     Gas          yes
# 13            BMW    4700.000      sedan      200   NaN  Petrol          yes
# 14  Mercedes-Benz   21500.000      sedan      159   1.8     Gas          yes
# 15            BMW   19999.000      sedan      290   4.8  Petrol          yes
# 16            BMW  129222.000      sedan        2   5.0  Petrol          yes
# 17  Mercedes-Benz   99999.000  crossover        0   3.0  Petrol          yes
# 18         Nissan   16600.000  crossover       83   2.0  Petrol          yes
# 19            BMW   73900.000      sedan       57   4.4  Petrol          yes
#
#     year      model  drive
# 0   2010       Kuga   full
# 1   2011    E-Class   rear
# 2   2008     CL 550   rear
# 3   2012      B 180  front
# 4   2013    E-Class    NaN
# 5   2013    X-Trail   full
# 6   2003     Accord  front
# 7   2011     Megane  front
# 8   2012    E-Class   rear
# 9   2010    E-Class   rear
# 10  2016    Qashqai  front
# 11  2011    E-Class   rear
# 12  2012    E-Class   rear
# 13  1996        316   rear
# 14  2012    E-Class   rear
# 15  2006        750   rear
# 16  2016        750   full
# 17  2016  GLE-Class   full
# 18  2013    X-Trail   full
# 19  2013         M5   rear

# %%
carsales.describe()  #displays summary statistics of all columns with numerical values..
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
carsales.info() # Showing non null count, datatype of every column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
carsales['body'].unique()  

# this command gives the types of cars considered in the dataset
# Out:
# array(['crossover', 'sedan', 'other', 'van', 'vagon', 'hatch'],
#       dtype=object)

# %%
carsales['car'].unique()


#these are the different car models considered in the dataset
# Out:
# array(['Ford', 'Mercedes-Benz', 'Nissan', 'Honda', 'Renault', 'BMW',
#        'Land Rover', 'Volkswagen', 'Audi', 'Chrysler', 'Jaguar',
#        'Mitsubishi', 'Kia', 'Porsche', 'Toyota', 'Hyundai', 'Opel',
#        'Chevrolet', 'Skoda', 'Daewoo', 'Mazda', 'Lexus', 'Infiniti',
#        'Tesla', 'Subaru', 'VAZ', 'Alfa Romeo', 'Smart', 'Peugeot',
#        'Suzuki', 'Chery', 'Bentley', 'Volvo', 'SsangYong', 'Fiat', 'ZAZ',
#        'Citroen', 'Dodge', 'Jeep', 'Great Wall', 'Seat', 'MINI', 'Dacia',
#        'Hummer', 'Geely', 'Maserati', 'BYD', 'Cadillac', 'Acura',
#        'Aston Martin', 'Rover', 'GAZ', 'GMC', 'Lincoln', 'ËUAZ',
#        'Moskvich-AZLK', 'FAW', 'UAZ', 'Rolls-Royce', 'TATA', 'ZX',
#        'Lifan', 'Mercury', 'Groz', 'Moskvich-Izh', 'Saab', 'Lancia',
#        'Aro', 'Ferrari', 'Isuzu', 'Bogdan', 'Dadi', 'Other-Retro', 'MG',
#        'Samand', 'JAC', 'Samsung', 'Lamborghini', 'Daihatsu', 'Hafei',
#        'SMA', 'Fisker', 'Changan', 'Barkas', 'Huanghai', 'Wartburg',
#        'Buick'], dtype=object)

# %%
carsales['engType'].unique()

# the below are the different engine types present in the data
# Out:
# array(['Gas', 'Petrol', 'Diesel', 'Other'], dtype=object)

# %%
carsales['engV'].unique()
# Out:
# array([ 2.5 ,  1.8 ,  5.5 ,   nan,  2.  ,  1.5 ,  2.2 ,  1.2 ,  4.8 ,
#         5.  ,  3.  ,  4.4 ,  1.6 ,  2.98,  2.4 ,  2.8 ,  3.5 ,  2.99,
#         1.9 ,  1.7 ,  4.5 ,  3.6 ,  1.4 ,  2.7 ,  4.  ,  3.8 ,  5.7 ,
#        99.99,  3.2 ,  3.7 ,  4.7 ,  1.  , 19.  ,  4.6 ,  0.11,  4.2 ,
#         0.8 ,  2.3 ,  6.2 ,  1.3 ,  6.  ,  2.6 ,  0.6 ,  1.25,  5.46,
#         6.3 ,  5.6 ,  8.3 ,  3.3 ,  1.1 ,  6.1 ,  0.65,  1.78,  2.1 ,
#         3.4 ,  7.  ,  1.46,  5.2 , 75.  ,  6.5 ,  1.23, 17.  ,  8.  ,
#         2.9 ,  1.34,  0.7 ,  1.39, 90.  ,  5.3 ,  4.67, 20.  , 14.  ,
#        11.5 ,  1.45,  9.  , 10.  ,  4.66, 15.  ,  0.9 , 12.  ,  2.57,
#         1.91,  1.33,  2.49,  1.12,  1.36,  2.14, 55.  ,  4.39,  6.75,
#         1.59, 28.  ,  8.7 ,  3.1 ,  2.15, 30.  ,  4.3 ,  4.25,  7.2 ,
#        85.  ,  5.4 , 66.  ,  2.69,  1.24, 18.  , 22.  , 70.  ,  2.44,
#         6.4 ,  1.35,  2.17,  2.46,  2.28,  1.79,  0.14,  1.31,  0.1 ,
#        74.  ])

# %%
carsales['registration'].unique()

# this command tells unique values of column " registration" 
# i.e if a given car model is registered or not
# Out:
# array(['yes', 'no'], dtype=object)

# %%
carsales['drive'].unique()

# under the column 'drive', we have 4 values giving the different modes of drive. and there is also a nan value which means null.
# Out:
# array(['full', 'rear', 'front', nan], dtype=object)

# %%
carsales['year'].unique()
# Out:
# array([2010, 2011, 2008, 2012, 2013, 2003, 2016, 1996, 2006, 2007, 2014,
#        2015, 1999, 2002, 1997, 2000, 2009, 1998, 2001, 2005, 2004, 1987,
#        1994, 1989, 1992, 1993, 1995, 1986, 1991, 1990, 1981, 1978, 1988,
#        1961, 1985, 1983, 1974, 1971, 1979, 1982, 1958, 1962, 1963, 1977,
#        1980, 1959, 1984, 1973, 1953, 1970, 1976, 1972, 1964, 1969, 1968,
#        1975], dtype=int64)

# %%
np.sort(carsales['year'].unique())  #[ we have data from  year 1953 to year 2016]
# Out:
# array([1953, 1958, 1959, 1961, 1962, 1963, 1964, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016], dtype=int64)

# %%
carsales['body'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9571    False
# 9572    False
# 9573    False
# 9574    False
# 9575    False
# Name: body, Length: 9576, dtype: bool

# %%
carsales.drop_duplicates(inplace=True)   #Drop the duplicate Value
carsales.shape
# Out:
# (9463, 10)

# %%
carsales.price.describe()
carsales[carsales.price == 0].car.count()
# Out:
# 240

# %%
carsales.engV.describe()
carsales[carsales.engV == 0].car.count()
# Out:
# 0

# %%
carsales.mileage.describe()
carsales[carsales.mileage == 0].car.count()                  #The output guves the
# Out:
# 310

# %% [markdown]
# Categorical Values to be fixed
#
# Drive
# engType

# %%
# lets Drop the duplicate Value

carsales.drop_duplicates(inplace=True)
carsales.shape
# Out:
# (9463, 10)

# %% [markdown]
# 6.1 Fixing engV missing / erroneous values

# %%
#Function that removes the outlier entries of engV and returns dataframe

def exclude_outliers_for_engV():
    return pd.DataFrame(carsales[(carsales.engV > 0.5) & (carsales.engV < 25)])

# Function that computes the mean value of engV based on make and model 

def compute_engV_mean(r):
    car_make = r.name[0]    
    car_model = r.name[1]
    if r.count() > 0:
        return round(r.mean(),2)
    else:
        engV_df = exclude_outliers_for_engV()
        engV_make = engV_df[engV_df.car == car_make].engV
        if engV_make.count() > 0:
            return round(engV_make.mean(),2)
        else:
            return round(engV_df.engV.mean(),2)
        

#Create a staging "engV mean" dataframe for  all combinations of make and model

engV_mean = carsales.groupby(['car','model']).engV.apply(compute_engV_mean).reset_index()
engV_mean.rename(columns={'engV':'engV_avg'}, inplace=True)
engV_mean.head(5)
# Out:
#      car model  engV_avg
# 0  Acura   MDX      3.62
# 1  Acura    RL      3.50
# 2  Acura    TL      3.20
# 3  Acura   TLX      2.40
# 4  Acura   ZDX      3.70

# %%
'''
Function that return engV value for missing records
'''
def get_missing_engV(r):
    if pd.isnull(r.engV):
        return engV_mean[(engV_mean.car == r.car) & (engV_mean.model == r.model)].engV_avg.values[0]
    else:
        return r.engV
    

'''
Fix the missing engV values
'''
print('--------------Before fix-----------------')
print(carsales[carsales.engV.isnull()].shape)

carsales.engV = carsales.apply(get_missing_engV, axis=1)
print('--------------After fix -----------------')
print(carsales[carsales.engV.isnull()].shape)
# Out:
# --------------Before fix-----------------
# (434, 10)
# --------------After fix -----------------
# (0, 10)

# %% [markdown]
# 6.2 Fixing price missing / erroneous values

# %%
#Function that computes the median value of price based on make and model 

def compute_price_median(r):
    car_make = r.name[0]    
    car_model = r.name[1]
    if (r.count() > 0) & (r.median() > 0):
        return r.median()
    else:
        price_make = carsales[carsales.car == car_make].price
        if price_make.median() > 0:
            return price_make.median()
        else:
            return carsales.price.median()

        
'''
Create a staging "Price median" dataframe for  all combinations of make and model
'''
price_median = carsales.groupby(['car','model']).price.apply(compute_price_median).reset_index()
price_median.rename(columns={'price':'price_median'}, inplace=True)
price_median.head(5)
# Out:
#      car model  price_median
# 0  Acura   MDX       17200.0
# 1  Acura    RL       13950.0
# 2  Acura    TL        8699.0
# 3  Acura   TLX       38200.0
# 4  Acura   ZDX       30999.0

# %%
# Function that return price value for missing records

def get_missing_price(r):
    if r.price == 0:
        return price_median[(price_median.car == r.car) & (price_median.model == r.model)].price_median.values[0]
    else:
        return r.price
    

# Fix the missing price values

print('--------------Before fix-----------------')
print(carsales[carsales.price == 0].shape)

carsales.price = carsales.apply(get_missing_price, axis=1)
print('--------------After fix -----------------')
print(carsales[carsales.price == 0].shape)
# Out:
# --------------Before fix-----------------
# (240, 10)
# --------------After fix -----------------
# (0, 10)

# %% [markdown]
# 6.3 Fixing mileage missing / erroneous values

# %%
# Function that computes the median value of mileage based on make and model 

def compute_mileage_median(r):
    car_make = r.name[0]    
    car_model = r.name[1]
    if (r.count() > 0) & (r.median() > 0):
        return r.median()
    else:
        mileage_make = carsales[carsales.car == car_make].mileage
        if mileage_make.median() > 0:
            return mileage_make.median()
        else:
            return carsales.mileage.median()
        

        
# Create a staging "mileage median" dataframe for  all combinations of make and model

mileage_median = carsales.groupby(['car','model']).mileage.apply(compute_mileage_median).reset_index()
mileage_median.rename(columns={'mileage':'mileage_median'}, inplace=True)
mileage_median.head(5)
# Out:
#      car model  mileage_median
# 0  Acura   MDX            85.0
# 1  Acura    RL           138.0
# 2  Acura    TL           145.0
# 3  Acura   TLX             4.0
# 4  Acura   ZDX            32.0

# %%
# Function that return mileage value for missing records

def get_missing_mileage(r):
    if r.mileage == 0:
        return mileage_median[(mileage_median.car == r.car) & (mileage_median.model == r.model)].mileage_median.values[0]
    else:
        return r.mileage
    


# Fix the missing price values

print('--------------Before fix-----------------')
print(carsales[carsales.mileage == 0].shape)

carsales.mileage = carsales.apply(get_missing_mileage, axis=1)
print('--------------After fix -----------------')
print(carsales[carsales.mileage == 0].shape)
# Out:
# --------------Before fix-----------------
# (310, 10)
# --------------After fix -----------------
# (0, 10)

# %% [markdown]
# 6.4 Fixing drive missing / erroneous values

# %%
# Function that removes the null entries of drive and returns dataframe

def get_clensed_data_for_drive():
    return pd.DataFrame(carsales[carsales.drive.isnull() == False])



# Function that computes the mode value of drive based on make and model 

def compute_drive(r):
    car_make = r.name[0]    
    car_model = r.name[1]
    if r.count() > 0:
        return r.mode()
    else:
        drive_df = get_clensed_data_for_drive()
        drive_make = drive_df[drive_df.car == car_make].drive
        if drive_make.count() > 0:
            return drive_make.mode()
        else:
            return drive_df.drive.mode()
        
        

# Create a staging "drive mode" dataframe for  all combinations of make and model

drive_mode = carsales.groupby(['car','model']).drive.apply(compute_drive).reset_index()
drive_mode.rename(columns={'drive':'drive_mode'}, inplace=True)
drive_mode.drop('level_2', axis=1)
# Out:
#        car       model drive_mode
# 0    Acura         MDX       full
# 1    Acura          RL       full
# 2    Acura          TL      front
# 3    Acura         TLX      front
# 4    Acura         ZDX       full
# ..     ...         ...        ...
# 914     ZX    LandMark       full
# 915   ËUAZ        1301       full
# 916   ËUAZ        1302       full
# 917   ËUAZ  969 Âîëûíü       full
# 918   ËUAZ        969Ì       full
#
# [919 rows x 3 columns]

# %%
# Function that return drive value for missing records

def get_missing_drive(r):
    if pd.isnull(r.drive):
        return drive_mode[(drive_mode.car == r.car) & (drive_mode.model == r.model)].drive_mode.values[0]
    else:
        return r.drive

# Fix the missing drive values

print('--------------Before fix-----------------')
print(carsales[carsales.drive.isnull()].shape)

carsales.drive = carsales.apply(get_missing_drive, axis=1)
print('--------------After fix -----------------')
print(carsales[carsales.drive.isnull()].shape)
# Out:
# --------------Before fix-----------------
# (510, 10)
# --------------After fix -----------------
# (0, 10)

# %% [markdown]
# 6.5 Fixing engType missing / erroneous values

# %%
#Function that removes the null entries of engType and returns dataframe

def get_clensed_data_for_engType():
    return pd.DataFrame(carsales[carsales.engType.isnull() == False])



#Function that computes the mode value of engType based on make and model 

def compute_engType(r):
    car_make = r.name[0]    
    car_model = r.name[1]
    if r.count() > 0:
        return r.mode()
    else:
        engType_df = get_clensed_data_for_engType()
        engType_make = engType_df[engType_df.car == car_make].engType
        if engType_make.count() > 0:
            return engType_make.mode()
        else:
            return engType_df.engType.mode()
        
        

#Create a staging "engType mode" dataframe for  all combinations of make and model

engType_mode = carsales.groupby(['car','model']).engType.apply(compute_engType).reset_index()
engType_mode.rename(columns={'engType':'engType_mode'}, inplace=True)
engType_mode.drop('level_2', axis=1)
# Out:
#        car       model engType_mode
# 0    Acura         MDX       Petrol
# 1    Acura          RL          Gas
# 2    Acura          TL          Gas
# 3    Acura         TLX       Petrol
# 4    Acura         ZDX        Other
# ..     ...         ...          ...
# 984     ZX    LandMark       Petrol
# 985   ËUAZ        1301       Petrol
# 986   ËUAZ        1302          Gas
# 987   ËUAZ  969 Âîëûíü       Petrol
# 988   ËUAZ        969Ì       Petrol
#
# [989 rows x 3 columns]

# %%
#Function that return engType value for missing records

def get_missing_engType(r):
    if pd.isnull(r.engType):
        return engType_mode[(engType_mode.car == r.car) & (engType_mode.model == r.model)].engType_mode.values[0]
    else:
        return r.engType
    

#Fix the missing engType values

print('--------------Before fix-----------------')
print(carsales[carsales.engType.isnull()].shape)

carsales.engType = carsales.apply(get_missing_engType, axis=1)
print('--------------After fix -----------------')
print(carsales[carsales.engType.isnull()].shape)
# Out:
# --------------Before fix-----------------
# (0, 10)
# --------------After fix -----------------
# (0, 10)

# %% [markdown]
# 7. Data Post-Profiling

# %%
carsales_Profile = pandas_profiling.ProfileReport(carsales)
carsales_Profile.to_file("CarSales_Post_Processing.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# 8. Exploratory Data Analysis

# %% [markdown]
# 8.1 Q - Which car manufacturer had highest sales?

# %%
df = pd.DataFrame(carsales.car.value_counts())
print(df.head())
# Out:
#                car
# Volkswagen     927
# Mercedes-Benz  885
# BMW            684
# Toyota         529
# VAZ            488

# %% [markdown]
# 8.2 Q - Analyize the sales of the brands

# %%
ax = df.head(10).plot.bar(figsize=(15,6))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/4), p.get_height()+5), rotation=0)
    
plt.title("Top 10 car brands on sale")
# Out:
# Text(0.5, 1.0, 'Top 10 car brands on sale')

# %% [markdown]
# From the dataset, the top performing car sales are from following manufacturers
#
# Volkswagen 927
#
# Mercedes-Benz 885
#
# BMW 684
#
# Toyota 529
#
# VAZ 488
#
# ...

# %% [markdown]
# 8.2 Q - What is the sales trend for top selling car manufacturers?

# %%
carsales_year_df = pd.DataFrame(carsales.groupby('year').car.value_counts())
carsales_year_df.rename(columns={'car':'sales'}, inplace=True)
carsales_year_df.reset_index(inplace=True)

# %%
topCarBrandSales = carsales_year_df[carsales_year_df.car.isin(df.head(5).index)]
fig, ax = plt.subplots(figsize=(20,8))
sns.lineplot(data=topCarBrandSales, x='year', y='sales', hue='car')
# Out:
# <AxesSubplot:xlabel='year', ylabel='sales'>

# %%
recentCarSalesTopBrands = carsales_year_df[carsales_year_df.car.isin(df.head(5).index) &  (carsales_year_df.year >= 2010)]
fig, ax = plt.subplots(figsize=(20,8))
sns.lineplot(data=recentCarSalesTopBrands, x='year', y='sales', hue='car')
# Out:
# <AxesSubplot:xlabel='year', ylabel='sales'>

# %% [markdown]
# Observations:
# 1. Overall Volkswagen used car are reported high sales and occupies 1st place, but the saleas are not performing very low in the recent past.
# 2. Mercedes-Benz significantly performing best sales and followed by BMW. These brands sales are sky rocketed and proven the customer trust.
# 3. Toyota cars are consistant in sales and keeping their position.
# 4. On flip side, Volkswagen and Vaz car sales are under performing in recently.

# %% [markdown]
# 8.3 Q - Which cars gain or loose the market?

# %%
#Function that returns perticular year sales

def get_SalesByYear(year):
    return carsales_year_df[carsales_year_df.year == year]


# Function that returns rank of a car

def get_CarSalesRankByYear(r):
    result = get_SalesByYear(r.year).sales.unique()
    i, = np.where(result == r.sales)
    return i[0]+1

# %%
# Add a new column called 'year_rank' to maintain year wise car sales rank

carsales_year_df['year_rank'] = carsales_year_df.apply(get_CarSalesRankByYear, axis=1)

# %%
# Top 5 ranked cars from 2009

recenttopcars = carsales_year_df[(carsales_year_df.year_rank <=5) &  (carsales_year_df.year >= 2009)].car.unique()
recenttopcars                                                                ************************************************
# Out:
# array(['Renault', 'Hyundai', 'Toyota', 'Volkswagen', 'Mercedes-Benz',
#        'Mitsubishi', 'Honda', 'BMW', 'Audi', 'Skoda', 'Nissan', 'Ford'],
#       dtype=object)

# %%
topcarbrands = carsales_year_df[(carsales_year_df.year_rank <=5) &  (carsales_year_df.year >= 1980)].car.unique()
topcarbrands
# Out:
# array(['VAZ', 'Audi', 'Ford', 'Mercedes-Benz', 'Moskvich-AZLK',
#        'Volkswagen', 'Lincoln', 'UAZ', 'GAZ', 'Opel', 'BMW', 'Nissan',
#        'Toyota', 'Mazda', 'Mitsubishi', 'Volvo', 'Renault', 'Fiat',
#        'Peugeot', 'Daewoo', 'Chevrolet', 'Skoda', 'Hyundai', 'Honda'],
#       dtype=object)

# %%
recentCarSalesRanks = carsales_year_df[carsales_year_df.car.isin(recenttopcars) & (carsales_year_df.year >= 2009)]

# %%
recentCarSalesRanks.pivot_table(index=['year'], columns={'car'}, values='sales')
# Out:
# car   Audi  BMW  Ford  Honda  Hyundai  Mercedes-Benz  Mitsubishi  Nissan  \
# year
# 2009    16   13     6     18       22             21          19      12
# 2010    25   26    20      7       12             33           6      16
# 2011    23   47    37     19       60             54          16      25
# 2012    19   35    32     17       38             44          12      22
# 2013    31   28    38      3       28             44          10      59
# 2014    16   22    18      4        9             36           5      29
# 2015    13   20    14      3        5             28           2      26
# 2016    13   51    14      9       26             75          10      12
#
# car   Renault  Skoda  Toyota  Volkswagen
# year
# 2009       23     15      22          22
# 2010       24     22      20          39
# 2011       44     36      30          97
# 2012       94     60      43         104
# 2013       35     20      45          69
# 2014       14     14      31          34
# 2015        3      6      21          23
# 2016       14     18      32          29

# %%
recentCarSalesRanks.pivot_table(index=['year'], columns={'car'}, values='year_rank')
# Out:
# car   Audi  BMW  Ford  Honda  Hyundai  Mercedes-Benz  Mitsubishi  Nissan  \
# year
# 2009     6    8    12      5        2              3           4       9
# 2010     4    3     7     13       10              2          14       8
# 2011    10    4     6     12        2              3          15       9
# 2012    12    7     8     14        6              4          16      11
# 2013     8    9     5     22        9              4          16       2
# 2014     7    5     6     14        9              1          13       4
# 2015     7    5     6     13       11              1          14       2
# 2016     8    2     7     11        5              1          10       9
#
# car   Renault  Skoda  Toyota  Volkswagen
# year
# 2009        1      7       2           2
# 2010        5      6       7           1
# 2011        5      7       8           1
# 2012        2      3       5           1
# 2013        6     11       3           1
# 2014        8      8       3           2
# 2015       13     10       4           3
# 2016        7      6       3           4

# %% [markdown]
# **Q)Analyse the sales of each brand **

# %%
sns.lmplot(data=recentCarSalesRanks, x='year', y='sales', col='car', fit_reg=True, hue='car', col_wrap=4, height=3)

# %% [markdown]
# We can divide brandsales in three categories
#
# i)increasing
#
# ii)no change
#
# ii)decreasing
#
# The brands which show an increasing sales are Toyota,Mercedes-Benz,BMW,Nissan,
#
# The brands which show decreasing sales are Renault,Volkswagen,Mitsubishi,Honda,Skoda
#
# Brands which show no change are Ford,Audi

# %% [markdown]
# **Q)Analyse the rank of each brand **

# %%
sns.lmplot(data=recentCarSalesRanks, x='year', y='year_rank', col='car', fit_reg=True, hue='car', col_wrap=4, height=3)

# %% [markdown]
# We can divide brands ranks in three categories
#
# i)increasing
#
# ii)no change
#
# iii)decreasing
#
# the brands which show an increasing trend are Benz, Hyundai , VW, Mitsubishi , Honda, Skoda
#
# the brands which show a decreasing trend are Toyota, BMW.
#
# the brand which show a neutral trend is audi

# %%
sns.catplot(x="year", y="year_rank", hue="car", kind="swarm", data=recentCarSalesRanks)

# %%
topcarbrands = pd.DataFrame(topcarbrands)
topcarbrands.rename(columns={0:'car'}, inplace=True)

# %%
def get_IsTopSelling(r):
    return r.car in recenttopcars

topcarbrands['is_top_selling'] = topcarbrands.apply(get_IsTopSelling, axis=1)

# %%
print(topcarbrands[topcarbrands.is_top_selling == False].car, topcarbrands[topcarbrands.is_top_selling == True].car)
# Out:
# 0               VAZ
# 4     Moskvich-AZLK
# 6           Lincoln
# 7               UAZ
# 8               GAZ
# 9              Opel
# 13            Mazda
# 15            Volvo
# 17             Fiat
# 18          Peugeot
# 19           Daewoo
# 20        Chevrolet
# Name: car, dtype: object 1              Audi
# 2              Ford
# 3     Mercedes-Benz
# 5        Volkswagen
# 10              BMW
# 11           Nissan
# 12           Toyota
# 14       Mitsubishi
# 16          Renault
# 21            Skoda
# 22          Hyundai
# 23            Honda
# Name: car, dtype: object

# %% [markdown]
# Observations:
# Following are the brands which loose the market
#
# VAZ
#
# Moskvich-AZLK
#
# Lincoln
#
# UAZ
#
# GAZ
#
# Opel
#
# Mazda
#
# Volvo
#
# Fiat
#
# Peugeot
#
# Daewoo
#
# Chevrolet
#
#
# **Following are the brands which gain/sustain the market
#
# Audi
#
# Ford
#
# Mercedes-Benz
#
# Volkswagen
#
# BMW
#
# Nissan
#
# Toyota
#
# Mitsubishi
#
# Renault
#
# Skoda
#
# Hyundai
#
# Honda

# %% [markdown]
# 8.4 Q - What are the top 10 Pemium cars & models and their sales?

# %%
carsales[carsales.price.isin(carsales.price.nlargest(10))].sort_values('price', ascending=False)
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 7621        Bentley  547800.0      sedan     20.0  6.75  Petrol          yes
# 1611        Bentley  499999.0  crossover     20.0  6.00  Petrol          yes
# 2637        Bentley  449999.0  crossover      1.0  6.00  Petrol          yes
# 4134        Bentley  449999.0  crossover     20.0  6.00  Petrol          yes
# 4325  Mercedes-Benz  300000.0      sedan     68.0  6.00  Petrol          yes
# 5849  Mercedes-Benz  300000.0      other     37.0  5.00  Petrol          yes
# 1891  Mercedes-Benz  295000.0      sedan     29.0  6.00  Petrol          yes
# 2165  Mercedes-Benz  295000.0      sedan     29.0  6.00  Petrol          yes
# 8205     Land Rover  285000.0  crossover     80.5  5.00  Petrol          yes
# 1478        Bentley  259000.0      sedan    415.0  6.00  Petrol          yes
#
#       year        model drive
# 7621  2016     Mulsanne  rear
# 1611  2016     Bentayga  full
# 2637  2016     Bentayga  full
# 4134  2016     Bentayga  full
# 4325  2011        S 600  rear
# 5849  2012        G 500  full
# 1891  2011        S 600  rear
# 2165  2011      S-Guard  rear
# 8205  2016  Range Rover  full
# 1478  2014  Flying Spur  full

# %%
cars_with_max_price_df = pd.DataFrame(carsales.groupby('car').price.max())
cars_with_max_price_df.reset_index(inplace=True)
cars_with_max_price_df.rename(columns={'price':'max_price'}, inplace=True)

# %%
def get_totalcarsales(r):
    return carsales[(carsales.car == r.car) & (carsales.price == r.max_price)].car.count()

def get_latestyearofsale(r):
    return carsales[(carsales.car == r.car) & (carsales.price == r.max_price)].year.max()

# %%
cars_with_max_price_df['total_sales'] = cars_with_max_price_df.apply(get_totalcarsales, axis=1)
cars_with_max_price_df['recently_sold_on'] = cars_with_max_price_df.apply(get_latestyearofsale, axis=1)

# %%
sns.scatterplot(data=cars_with_max_price_df.sort_values('max_price', ascending=False).head(10), x='recently_sold_on', y='max_price', hue='car')
# Out:
# <AxesSubplot:xlabel='recently_sold_on', ylabel='max_price'>

# %% [markdown]
# 8.5 Q - What are the sales & revenue in each segment of class ?

# %%
'''
Fuction that computes the class of the car based on price
Rules:
    -- Economy --> Price less than 10000 
    -- Luxury  --> Price above 10000 and below 30000
    -- Premium --> Price above 30000
'''
def classify_class(r):
    if r.price <= 10000:
        return "Economy"
    elif (r.price > 10000) & (r.price <= 30000):
        return "Luxury"
    else:
        return "Premium"
    
    # Set new column called 'class' for defining the sement

carsales["class"] = carsales.apply(classify_class, axis=1)

# %%
carsales.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover     68.0  2.50     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan    173.0  1.80     Gas          yes
# 2  Mercedes-Benz  35000.0      other    135.0  5.50  Petrol          yes
# 3  Mercedes-Benz  17800.0        van    162.0  1.80  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon     91.0  2.57   Other          yes
#
#    year    model  drive    class
# 0  2010     Kuga   full   Luxury
# 1  2011  E-Class   rear   Luxury
# 2  2008   CL 550   rear  Premium
# 3  2012    B 180  front   Luxury
# 4  2013  E-Class   rear  Premium

# %%
ax = carsales["class"].value_counts().plot.bar(figsize=(6,4))
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/3), p.get_height()+10), rotation=0)
    
plt.title("Car sales based on Class")
# Out:
# Text(0.5, 1.0, 'Car sales based on Class')

# %%
revenueByClass_df = carsales.groupby('class').price.sum()
plt.title('Revenue against Class')
print(revenueByClass_df.plot.pie(autopct='%1.1f%%'))
# Out:
# AxesSubplot(0.260833,0.125;0.503333x0.755)

# %% [markdown]
# # Observations:
# Economy Cars are best selling segment followed by Luxury and Premium
# Though the economy car sales are predominant in sales, but revenues are not impressive.
# Economy - 18.6%
# Luxury - 37.2%
# Premium - 44.2%

# %% [markdown]
# # 8.6 Q - What is the revenue generated in each segment of class ?

# %%
pvt_classyear_sales = carsales.pivot_table(index=['year','class'],  values="car", aggfunc='count')
pvt_classyear_sales.reset_index(inplace=True)
pvt_classyear_sales.rename(columns={"car":"car_sales"}, inplace=True)

# %%
# Function that returns revenue of a perticular segment in a specific year

def get_revenuebyclass(r):
    return carsales[(carsales['class'] == r['class']) & (carsales.year == r.year)].price.sum()

# %%
pvt_classyear_sales['revenue'] = pvt_classyear_sales.apply(get_revenuebyclass, axis=1)

# %%
def get_detailsbyclass(cls):
    return pvt_classyear_sales[pvt_classyear_sales['class'] == cls]

def get_detailsbyclass(cls, year):
    return pvt_classyear_sales[(pvt_classyear_sales['class'] == cls) & (pvt_classyear_sales.year >= year)]

# %%
fig, ax = plt.subplots(figsize=(16,5))
sns.lineplot(data=pvt_classyear_sales[pvt_classyear_sales.year >= 1990], x='year', y='car_sales', hue='class')
# Out:
# <AxesSubplot:xlabel='year', ylabel='car_sales'>

# %%
fig, ax = plt.subplots(figsize=(16,5))
sns.lineplot(data=pvt_classyear_sales[pvt_classyear_sales.year >= 1990], x='year', y='revenue', hue='class')
# Out:
# <AxesSubplot:xlabel='year', ylabel='revenue'>

# %% [markdown]
# # 8.7 Q - What is the sales trend based on body ?

# %%
carsalesbybody_df = carsales.pivot_table(index=['body'],  values="car", aggfunc='count')
carsalesbybody_df.reset_index(inplace=True)
carsalesbybody_df.rename(columns={'car':'sales'}, inplace=True)

# %%
recent_carsalesbybody_df = carsales[carsales.year > 2010].pivot_table(index=['body'],  values="car", aggfunc='count')
recent_carsalesbybody_df.reset_index(inplace=True)
recent_carsalesbybody_df.rename(columns={'car':'sales'}, inplace=True)

# %%
pvt_bodyyear_sales = carsales.pivot_table(index=['year','body'],  values="car", aggfunc='count')
pvt_bodyyear_sales.rename(columns={"car":"car_sales"}, inplace=True)
pvt_bodyyear_sales.reset_index(inplace=True)

def get_sales_by_body(body):
    return pvt_bodyyear_sales[pvt_bodyyear_sales['body'] == body]

# crossover, sedan, van, vagon, hatch, other

# %%
fig, ax = plt.subplots(figsize=(16,5))
sns.barplot(data=carsalesbybody_df, x='body', y='sales')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/3), p.get_height()+10), rotation=0)

plt.title('Overall car sales based on body type')
# Out:
# Text(0.5, 1.0, 'Overall car sales based on body type')

# %%
fig, ax = plt.subplots(figsize=(16,5))
sns.barplot(data=recent_carsalesbybody_df, x='body', y='sales')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() + (p.get_width()/3), p.get_height()+10), rotation=0)

plt.title('Recent 5 years car sales based on body type')
# Out:
# Text(0.5, 1.0, 'Recent 5 years car sales based on body type')

# %%
fig, ax = plt.subplots(figsize=(16,5))
sns.lineplot(data=pvt_bodyyear_sales[pvt_bodyyear_sales.year >= 1990], x='year', y='car_sales', hue='body')
# Out:
# <AxesSubplot:xlabel='year', ylabel='car_sales'>

# %%
fig, ax = plt.subplots(figsize=(16,5))
sns.lineplot(data=pvt_bodyyear_sales[(pvt_bodyyear_sales.year >= 1990) & (pvt_bodyyear_sales.body == 'vagon')], x='year', y='car_sales')
sns.lineplot(data=pvt_bodyyear_sales[(pvt_bodyyear_sales.year >= 1990) & (pvt_bodyyear_sales.body == 'van')], x='year', y='car_sales')
sns.lineplot(data=pvt_bodyyear_sales[(pvt_bodyyear_sales.year >= 1990) & (pvt_bodyyear_sales.body == 'other')], x='year', y='car_sales')
# Out:
# <AxesSubplot:xlabel='year', ylabel='car_sales'>

# %% [markdown]
# # Observations:
# 1. Overall Crossover, Sedan and hatches are more demanded car body types
# 2. It is observed that recent crossover sales are skyrocketing.
# 3. Van and Vagon body types are loosing sales and other cars are gaining market.
# 4. So possible reason of declining sales are Van & Vagon type cars are loosing market.

# %% [markdown]
# 8.8 Q - What are the best mileage cars in each segment of 'class' ?

# %%
besteconomycars = carsales.pivot_table(index=['class','car'],  values="mileage", aggfunc='max')
besteconomycars.reset_index(inplace=True)

# %%
# Return upper whisker for mileage by class
def get_best_carandmileage_byclass(cls):
    clsmileage = besteconomycars[besteconomycars['class'] == cls]
    maxval = clsmileage.mileage.max()
    thirdQurtile = clsmileage.describe().iloc[6].mileage   
    firstQurtile = clsmileage.describe().iloc[4].mileage     
    iqr = thirdQurtile - firstQurtile
    upperwhisker = min(maxval, thirdQurtile + (1.5 * iqr))
    return upperwhisker

# Get closest upper whisker milage results
def get_closest(cls, val):
    cls_df = carsales[carsales['class'] == cls]
    return cls_df.iloc[(cls_df['mileage']-val).abs().argsort()[:2]]

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(data=besteconomycars, x='class', y='mileage', palette='rainbow')

plt.title('Mileage vs Class')
# Out:
# Text(0.5, 1.0, 'Mileage vs Class')

# %%
print(besteconomycars[besteconomycars['class'] == 'Economy'].describe())
print('---------------------')
print(besteconomycars[besteconomycars['class'] == 'Luxury'].describe())
print('---------------------')
print(besteconomycars[besteconomycars['class'] == 'Premium'].describe())
# Out:
#           mileage
# count   73.000000
# mean   317.383562
# std    224.147684
# min     37.000000
# 25%    145.000000
# 50%    286.000000
# 75%    450.000000
# max    999.000000
# ---------------------
#           mileage
# count   52.000000
# mean   258.346154
# std    221.197621
# min      1.000000
# 25%    128.000000
# 50%    206.500000
# 75%    276.250000
# max    850.000000
# ---------------------
#           mileage
# count   37.000000
# mean   187.540541
# std    244.048276
# min     11.000000
# 25%     55.000000
# 50%    122.000000
# 75%    165.000000
# max    980.000000

# %%
get_closest('Economy', get_best_carandmileage_byclass('Economy'))
# Out:
#       car   price   body  mileage  engV engType registration  year  \
# 4572  Kia  7150.0  hatch    920.0   1.4  Petrol          yes  2008
# 7970  ZAZ  1600.0  sedan    930.0   1.2     Gas          yes  2006
#
#              model  drive    class
# 4572          Ceed  front  Economy
# 7970  1103 Ñëàâóòà  front  Economy

# %%
get_closest('Luxury', get_best_carandmileage_byclass('Luxury'))
# Out:
#                 car    price   body  mileage  engV engType registration  year  \
# 898      Volkswagen  12900.0  other    440.0   1.4  Petrol          yes  2008
# 5009  Mercedes-Benz  12300.0  sedan    423.0   5.0     Gas          yes  1997
#
#       model  drive   class
# 898     Eos  front  Luxury
# 5009  S 500   rear  Luxury

# %%
get_closest('Premium', get_best_carandmileage_byclass('Premium'))
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 1033  Mercedes-Benz  32000.0        van    255.0   3.0  Diesel          yes
# 8948  Mercedes-Benz  32500.0  crossover    254.0   3.2  Diesel          yes
#
#       year               model drive    class
# 1033  2008  Sprinter 318 ïàññ.  rear  Premium
# 8948  2008              GL 320  full  Premium

# %% [markdown]
# # Observations:
# Following are the best mileage given cars in each segment.
# 1.  Economy --> Kia - Ceed & ZAZ - 1103
# 2.  Luxury --> Volkswagen - Eos & Mercedes-Benz - S 500
# 3.  Premium --> Mercedes-Benz - Sprinter 318 & GL 320

# %% [markdown]
# # 8.9 Q - Used car registrations by class ?

# %%
f,ax = plt.subplots(1,3,figsize=(16,8))
carsales[carsales['class'] == 'Economy'].registration.value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[0],shadow=True)
carsales[carsales['class'] == 'Luxury'].registration.value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[1],shadow=True)
carsales[carsales['class'] == 'Premium'].registration.value_counts().plot.pie(explode=[0,0.2],autopct='%1.1f%%',ax=ax[2],shadow=True)
ax[0].set_title('Registration (Economy)')
ax[1].set_title('Registration (Luxury)')
ax[2].set_title('Registration (Premium)')
# Out:
# Text(0.5, 1.0, 'Registration (Premium)')

# %% [markdown]
# # Observations:
# Majority of unregistered cars were from Economy class

# %% [markdown]
# # 8.10 Q - Derive the correlation between sales and other values ?

# %% [markdown]
# Class wise car prices

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=carsales, x='year', y='price', hue='class')
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %% [markdown]
# Engine Type wise car prices

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=carsales, x='year', y='price', hue='engType')
plt.title("Overall car prices by engine type")
# Out:
# Text(0.5, 1.0, 'Overall car prices by engine type')

# %%
# For last 10 years car sales based on engType, body, class and average price

salesByEngTypeBodyClass_df = carsales[carsales.year.isin(pd.DataFrame(carsales.year.unique())[0].nlargest(10))]
salesByYearBodyClass = salesByEngTypeBodyClass_df.pivot_table(index=['year','engType'], values='price', aggfunc='mean')
salesByYearBodyClass.reset_index(inplace=True)

# %%
plt.figure(figsize=(16,8))
sns.lineplot(data=salesByYearBodyClass, x='year', y='price', hue='engType')
plt.title("Latest 10 year car prices by engine type")
# Out:
# Text(0.5, 1.0, 'Latest 10 year car prices by engine type')

# %%
classsalesByEngType_5year = carsales[carsales.year.isin(pd.DataFrame(carsales.year.unique())[0].nlargest(10))].groupby('year')['engType'].value_counts()
carsalesEngType = pd.DataFrame(classsalesByEngType_5year)
carsalesEngType.rename(columns={'engType':'sales'}, inplace=True)
carsalesEngType.reset_index(inplace=True)

# %%
sns.lmplot(data=carsalesEngType, x='year', y='sales', hue='engType', height=8)
plt.title("Latest 10 year car sales by engine type")
# Out:
# Text(0.5, 1.0, 'Latest 10 year car sales by engine type')

# %%
fig, ax = plt.subplots(figsize=(16,8))

sns.barplot(x="engType", y="price", hue= "body", palette="husl",data=carsales)
ax.set_title("Average price of vehicles by engine type and drive",fontdict= {'size':12})
ax.xaxis.set_label_text("Type Of Fuel",fontdict= {'size':14})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':14})
ticks = plt.setp(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# car sales by drive

# %%
#fig, ax = plt.subplots(figsize=(16,8))
sns.countplot(x='drive', data=carsales, orient='h')
plt.title("Overall car sales by drive")
# Out:
# Text(0.5, 1.0, 'Overall car sales by drive')

# %%
#fig, ax = plt.subplots(figsize=(16,8))
sns.countplot(x='drive', data=carsales[carsales.year > 2010], orient='h')
plt.title("Latest 5 year car sales by drive")
# Out:
# Text(0.5, 1.0, 'Latest 5 year car sales by drive')

# %% [markdown]
# Yearly car price and sales by engine type

# %%
def get_carpricesales(et):
    return salesByYearBodyClass[salesByYearBodyClass.engType == et]

def get_priceByYearEngType(r):
    return carsales[(carsales.year == r.year) & (carsales.engType == r.engType)].car.count()

def plotGraph(et):
    carSalesPrice = get_carpricesales(et)
    plt.figure(figsize=(20, 8))
    ax = carSalesPrice.plot('year','sales')
    carSalesPrice.plot('year','price',secondary_y=True, ax=ax)
    plt.legend()

# %%
salesByYearBodyClass['sales'] = salesByYearBodyClass.apply(get_priceByYearEngType, axis=1)

# %%
petrolcarSalesPrice = get_carpricesales('Petrol')
dieselCarSalesPrice = get_carpricesales('Diesel')
gasCarSalesPrice = get_carpricesales('Gas')
otherCarSalesPrice = get_carpricesales('Other')

plt.figure(figsize=(16, 8))
ax = petrolcarSalesPrice.plot('year','sales', color='r')
petrolcarSalesPrice.plot('year','price', color='g', secondary_y=True, ax=ax)

ax = dieselCarSalesPrice.plot('year','sales', color='orange')
dieselCarSalesPrice.plot('year','price', color='purple', secondary_y=True, ax=ax)

ax = gasCarSalesPrice.plot('year','sales', color='aqua')
gasCarSalesPrice.plot('year','price', color='red', secondary_y=True, ax=ax)

ax = otherCarSalesPrice.plot('year','sales', color='lightgreen')
otherCarSalesPrice.plot('year','price', color='purple', secondary_y=True, ax=ax)

plt.legend()

# %%
sns.scatterplot(data=salesByYearBodyClass, x='sales', y='price', hue='engType')
# Out:
# <AxesSubplot:xlabel='sales', ylabel='price'>

# %% [markdown]
# # Sales percentage by engine type

# %%
carsalesrecent_df = carsales[carsales.year.isin(pd.DataFrame(carsales.year.unique())[0].nlargest())]
carsalesrecent_pv = carsalesrecent_df.pivot_table(index=['engType'], values='car', aggfunc="count")
carsalesrecent_pv.rename(columns={'car':'sales'}, inplace=True)

# %%
carsalesold_df = carsales[carsales.year < 2012]
carsalesold_pv = carsalesold_df.pivot_table(index=['engType'], values='car', aggfunc="count")
carsalesold_pv.rename(columns={'car':'sales'}, inplace=True)

# %%
carsalesold_pv.plot.pie(y='sales', x='engType', autopct="%0.0f%%")
# Out:
# <AxesSubplot:ylabel='sales'>

# %% [markdown]
# # Observations:
# 1. There are no cars available at 20000 to 36000 price bracket, which is high dense price range
# 2. Though the cars with Gas engine type sold at most economical price, in the recent days customers are not preferred.
# 3. Most preferred engine type is Petrol and Diesel.
# 4. Other engine type cars are gradually increasing in sales despite of its high price.
# 5. Front & Full wheel drive cars mostly opted by customers. Rear wheel drive car sales are declined drastically in last 5 years
# 6. Most sales happening price range is between 10000 to 40000
